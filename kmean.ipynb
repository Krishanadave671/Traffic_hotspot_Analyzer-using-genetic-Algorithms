# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\krish\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\krish\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\krish\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\krish\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.23.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\krish\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\krish\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import folium
from sklearn.cluster import KMeans
import pandas as pd

# %%
# Load data
data = pd.read_csv('normalized_dataset.csv')

# Define number of clusters
num_clusters = 5

# Extract features
features = data[['latitude', 'longitude']]

# Cluster data
kmeans = KMeans(n_clusters=num_clusters).fit(features)
data['Cluster'] = kmeans.labels_

data.head(10)
data.to_csv('k_means_output.csv', index= False)
# Out:
# C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data
# Out:
#                 location  frequency  latitude  longitude  Cluster
# 0            azad maidan   0.000000  0.071301   0.234205        3
# 1                 bandra   0.432432  0.415871   0.265475        0
# 2               bhoiwada   0.027027  0.315334   0.367581        0
# 3                    bkc   0.243243  0.453759   0.403957        0
# 4               borivali   0.270270  0.937053   0.374601        2
# 5                byculla   0.000000  0.184666   0.216337        3
# 6                chembur   0.729730  0.439439   0.654116        1
# 7            chunabhatti   0.000000  0.397375   0.548181        1
# 8                 colaba   0.054054  0.000000   0.173580        3
# 9               d.b.marg   0.027027  0.083234   0.230377        3
# 10                 dadar   0.675676  0.311158   0.279515        0
# 11               dahisar   0.243243  1.000000   0.388641        2
# 12                deonar   0.000000  0.406921   0.677090        1
# 13               dharavi   0.081081  0.369928   0.362476        0
# 14              dindoshi   0.216216  0.767601   0.406509        2
# 15             ghatkopar   0.108108  0.511635   0.698149        1
# 16              goregaon   0.513514  0.744630   0.323548        2
# 17            jogeshwari   0.297297  0.656026   0.320357        2
# 18             kalbadevi   0.054054  0.103520   0.209317        3
# 19             kandivali   0.189189  0.875298   0.278239        2
# 20            kanjurmarg   0.000000  0.645585   0.825782        4
# 21                 kurla   0.297297  0.483890   0.514997        1
# 22                 mahim   0.054054  0.360680   0.266114        0
# 23                 malad   0.540541  0.810561   0.319081        2
# 24            malbarhill   0.000000  0.128878   0.000000        3
# 25              mankhurd   0.162162  0.398568   0.892151        4
# 26           marinedrive   0.000000  0.088604   0.160817        3
# 27               matunga   0.351351  0.334129   0.362476        0
# 28                   MHB   0.000000  0.794153   0.283344        2
# 29                  MIDC   0.324324  0.606504   0.422463        1
# 30                mulund   0.351351  0.766110   1.000000        4
# 31            D.N. nagar   1.000000  0.640513   0.195916        2
# 32               nagpada   0.054054  0.159010   0.178047        3
# 33              oshiwara   0.189189  0.713007   0.289087        2
# 34                 powai   0.243243  0.607697   0.693682        1
# 35              pydhunie   0.108108  0.117243   0.221442        3
# 36  sahar police station   0.405405  0.552804   0.405871        0
# 37              sakinaka   0.216216  0.553699   0.589662        1
# 38            samtanagar   0.270270  0.878580   0.372687        2
# 39             Santacruz   0.432432  0.497613   0.274410        0
# 40                tardeo   0.297297  0.166468   0.095086        3
# 41               Trombey   0.000000  0.463902   0.098915        0
# 42                vakola   0.243243  0.491647   0.355456        0
# 43              vikhroli   0.189189  0.607697   0.828334        4
# 44                wadala   0.081081  0.328162   0.417358        0
# 45                 worli   0.216216  0.288484   0.126356        3
